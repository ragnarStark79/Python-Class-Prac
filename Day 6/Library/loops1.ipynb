# %%
# while loop password matcher
correct_password = "secure123"
user_password = ""
while user_password != correct_password:
  user_password = input("Enter the password: ")
  if user_password != correct_password:
    print("Access denied.")
print("Access granted.")
# Out:
# Access granted.
